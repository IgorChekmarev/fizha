# %%
import pandas as pd

# Читаем Excel файл
df = pd.read_excel('2.1ready.xlsx')

# В данных первый столбец содержит "dp" и значения, нам нужны все столбцы
# Разделяем строки по пробелам и создаем новый DataFrame
data = []
for index, row in df.iterrows():
    # Получаем строку из первого (и единственного) столбца
    text = str(row[0])
    
    # Разбиваем по пробелам
    parts = text.strip().split()
    
    # Проверяем, что строка начинается с "dp" и содержит достаточно частей
    if len(parts) >= 4 and parts[0].lower() == 'dp':
        # Берем следующие 3 части (время, напряжение, ток)
        try:
            time = float(parts[1])
            voltage = float(parts[2])
            current = float(parts[3])
            data.append([time, voltage, current])
        except ValueError:
            print(f"Ошибка преобразования в строке: {text}")

# Создаем новый DataFrame
result_df = pd.DataFrame(data, columns=['Время, с', 'Напряжение, В', 'Ток, А'])
print(result_df)
# Сохраняем результат
result_df.to_csv('2.1readydata.csv', index=False, sep=';', encoding='utf-8-sig')
result_df.to_excel('2.1readydata.xlsx', index=False)

print(f"Извлечено строк: {len(result_df)}")
print("\nПервые 5 строк:")
print(result_df.head())
print("\nПоследние 5 строк:")
print(result_df.tail())
print("\nСтатистика:")
print(result_df.describe())
# Out:
#        Время, с  Напряжение, В    Ток, А
# 0      0.359000      -2.299140 -0.024976
# 1      0.548000      -2.300563 -0.027747
# 2      0.728000      -2.300563 -0.025906
# 3      0.908000      -2.300563 -0.025544
# 4      1.088000      -2.300563 -0.025378
# ..          ...            ...       ...
# 884  159.488007      -2.300721 -0.022617
# 885  159.667999      -2.300721 -0.022617
# 886  159.848007      -2.300721 -0.022632
# 887  160.028000      -2.300721 -0.022632
# 888  160.207993      -2.300721 -0.022617
#
# [889 rows x 3 columns]
# Извлечено строк: 889
#
# Первые 5 строк:
#    Время, с  Напряжение, В    Ток, А
# 0     0.359      -2.299140 -0.024976
# 1     0.548      -2.300563 -0.027747
# 2     0.728      -2.300563 -0.025906
# 3     0.908      -2.300563 -0.025544
# 4     1.088      -2.300563 -0.025378
#
# Последние 5 строк:
#        Время, с  Напряжение, В    Ток, А
# 884  159.488007      -2.300721 -0.022617
# 885  159.667999      -2.300721 -0.022617
# 886  159.848007      -2.300721 -0.022632
# 887  160.028000      -2.300721 -0.022632
# 888  160.207993      -2.300721 -0.022617
#
# Статистика:
#          Время, с  Напряжение, В      Ток, А
# count  889.000000     889.000000  889.000000
# mean    80.287990      -2.300637   -0.023621
# std     46.219786       0.000095    0.000744
# min      0.359000      -2.300721   -0.027747
# 25%     40.327999      -2.300721   -0.024141
# 50%     80.288002      -2.300563   -0.023522
# 75%    120.248001      -2.300563   -0.022994
# max    160.207993      -2.299140   -0.022617
# C:\Users\User\AppData\Local\Temp\ipykernel_3492\2073384510.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text = str(row[0])

# %%
import pandas as pd
result_df = pd.read_excel('2.1readydata.xlsx')

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.plot(result_df['Время, с'], result_df['Напряжение, В'])
plt.title('Зависимость напряжения от времени')
plt.xlabel('Время, с')
plt.ylabel('Напряжение, В')
plt.savefig("Напряжение от времени 3 цикла", bbox_inches='tight')

plt.show()

# 3. График C от 
plt.plot(result_df['Время, с'], result_df['Ток, А'])
plt.title('Зависимость тока от времени')
plt.xlabel('Время, с')
plt.ylabel('Ток, А')
plt.savefig("Ток от времени 3 цикла", bbox_inches='tight')

plt.show()

plt.plot(result_df['Напряжение, В'], result_df['Ток, А'])
plt.title('Зависимость тока от напряжения (Вольт-амперная характеристика)')
plt.xlabel('Напряжение, В')
plt.ylabel('Ток, А')
plt.savefig("Ток от напряжения 3 цикла", bbox_inches='tight')

plt.show()

plt.plot(result_df['Ток, А'], result_df['Напряжение, В'])
plt.title('Зависимость напряжения от тока')
plt.xlabel('Ток, А')
plt.ylabel('Напряжение, В')
plt.savefig("Ток от напряжения 3 цикла", bbox_inches='tight')

plt.show()
