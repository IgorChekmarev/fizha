# %%
import pandas as pd

# Читаем Excel файл
df = pd.read_excel('2a.xlsx', sheet_name='cy3', header=None)

# В данных первый столбец содержит "dp" и значения, нам нужны все столбцы
# Разделяем строки по пробелам и создаем новый DataFrame
data = []
for index, row in df.iterrows():
    # Получаем строку из первого (и единственного) столбца
    text = str(row[0])
    
    # Разбиваем по пробелам
    parts = text.strip().split()
    
    # Проверяем, что строка начинается с "dp" и содержит достаточно частей
    if len(parts) >= 4 and parts[0].lower() == 'dp':
        # Берем следующие 3 части (время, напряжение, ток)
        try:
            time = float(parts[1])
            voltage = float(parts[2])
            current = float(parts[3])
            data.append([time, voltage, current])
        except ValueError:
            print(f"Ошибка преобразования в строке: {text}")

# Создаем новый DataFrame
result_df = pd.DataFrame(data, columns=['Время, с', 'Напряжение, В', 'Ток, А'])
print(result_df)
# Сохраняем результат
result_df.to_csv('2a3cy.csv', index=False, sep=';', encoding='utf-8-sig')
result_df.to_excel('2a3cy.xlsx', index=False)

print(f"Извлечено строк: {len(result_df)}")
print("\nПервые 5 строк:")
print(result_df.head())
print("\nПоследние 5 строк:")
print(result_df.tail())
print("\nСтатистика:")
print(result_df.describe())
# Out:
#       Время, с  Напряжение, В    Ток, А
# 0     0.104000       0.194242 -0.000677
# 1     0.208000       0.189185 -0.000896
# 2     0.312000       0.183969 -0.001118
# 3     0.416000       0.178912 -0.001343
# 4     0.520000       0.173854 -0.001568
# ..         ...            ...       ...
# 919  95.275002       0.218266  0.000240
# 920  95.288002       0.215105  0.000109
# 921  95.391998       0.209889 -0.000079
# 922  95.496002       0.204832 -0.000271
# 923  95.599998       0.199774 -0.000482
#
# [924 rows x 3 columns]
# Извлечено строк: 924
#
# Первые 5 строк:
#    Время, с  Напряжение, В    Ток, А
# 0     0.104       0.194242 -0.000677
# 1     0.208       0.189185 -0.000896
# 2     0.312       0.183969 -0.001118
# 3     0.416       0.178912 -0.001343
# 4     0.520       0.173854 -0.001568
#
# Последние 5 строк:
#       Время, с  Напряжение, В    Ток, А
# 919  95.275002       0.218266  0.000240
# 920  95.288002       0.215105  0.000109
# 921  95.391998       0.209889 -0.000079
# 922  95.496002       0.204832 -0.000271
# 923  95.599998       0.199774 -0.000482
#
# Статистика:
#          Время, с  Напряжение, В      Ток, А
# count  924.000000     924.000000  924.000000
# mean    47.938583      -0.900496   -0.001138
# std     27.689579       0.693642    0.002325
# min      0.104000      -2.099050   -0.012040
# 25%     24.000000      -1.500479   -0.000967
# 50%     47.954000      -0.900880   -0.000298
# 75%     71.919998      -0.300886   -0.000221
# max     95.599998       0.298081    0.004432

# %%
result_df = pd.read_excel('2aa.xlsx')
result_df1 = pd.read_excel('2.a.xlsx')

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.plot(result_df['Время, с'], result_df['Напряжение, В'])
plt.title('Зависимость напряжения от времени')
plt.xlabel('Время, с')
plt.ylabel('Напряжение, В')
plt.savefig("Напряжение от времени 3 цикла", bbox_inches='tight')

plt.show()

# 3. График C от 
plt.plot(result_df['Время, с'], result_df['Ток, А'])
plt.title('Зависимость тока от времени')
plt.xlabel('Время, с')
plt.ylabel('Ток, А')
plt.savefig("Ток от времени 3 цикла", bbox_inches='tight')

plt.show()

plt.plot(result_df['Напряжение, В'], result_df['Ток, А'])
plt.title('Зависимость тока от напряжения (Вольт-амперная характеристика)')
plt.xlabel('Напряжение, В')
plt.ylabel('Ток, А')
plt.savefig("Ток от напряжения 3 цикла", bbox_inches='tight')

plt.show()

plt.plot(result_df1['Время, с'], result_df1['Напряжение, В'])
plt.title('Зависимость напряжения от времени')
plt.xlabel('Время, с')
plt.ylabel('Напряжение, В')
plt.savefig("Напряжение от времени 1 цикл", bbox_inches='tight')

plt.show()

# 3. График C от 
plt.plot(result_df1['Время, с'], result_df1['Ток, А'])
plt.title('Зависимость тока от времени')
plt.xlabel('Время, с')
plt.ylabel('Ток, А')
plt.savefig("Ток от времени 1 цикл", bbox_inches='tight')

plt.show()

plt.plot(result_df1['Напряжение, В'], result_df1['Ток, А'])
plt.title('Зависимость тока от напряжения (Вольт-амперная характеристика)')
plt.xlabel('Напряжение, В')
plt.ylabel('Ток, А')
plt.savefig("Ток от напряжения 1 цикл", bbox_inches='tight')

plt.show()
